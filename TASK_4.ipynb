# %% [markdown]
# **PRODIGY INFOTECH INTERNSHIP**
#
# **TASK 4**:Analyze and visualize sentiment patterns in social media data to understand public opinion and attitudes towards specific topics or brands.
#
# **DONE BY**: Girish.V

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORTING AMAZON REVIEW DATASET**

# %%
df=pd.read_csv('Amazon_Review.csv')
df
# Out:
#        Unique_ID Category                           Review_Header  \
# 0         136040  smartTv                                Nice one
# 1         134236   mobile  Huge battery life with amazing display
# 2         113945    books                              Four Stars
# 3         168076  smartTv                            Nice quality
# 4         157302    books                               Nice book
# ...          ...      ...                                     ...
# 60884     148315  smartTv                                    Good
# 60885     162092  smartTv                              Five Stars
# 60886     164387   mobile                           Best in prise
# 60887     133063  smartTv                           Not gud pbone
# 60888     167823   mobile                           Not recommend
#
#                                              Review_text  Rating Own_Rating
# 0                                             I liked it       5   Positive
# 1      I bought the phone on Amazon and been using my...       5   Positive
# 2      Awesome book at reasonable price, must buy ......       4   Positive
# 3                                                   good       5   Positive
# 4      The book is fine,not bad,contains nice concept...       3    Neutral
# ...                                                  ...     ...        ...
# 60884                                                 Ok       4   Positive
# 60885  Value for money, using since more than 4 month...       5   Positive
# 60886                                 Very nice products       5   Positive
# 60887         Heating problem. Battery backup less than.       3    Neutral
# 60888  fingerprint reader average Camera quality belo...       3    Neutral
#
# [60889 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60889 entries, 0 to 60888
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unique_ID      60889 non-null  int64
#  1   Category       60889 non-null  object
#  2   Review_Header  60886 non-null  object
#  3   Review_text    60861 non-null  object
#  4   Rating         60889 non-null  int64
#  5   Own_Rating     60889 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 2.8+ MB

# %%
df.tail(10)
# Out:
#        Unique_ID            Category                    Review_Header  \
# 60879     150254             smartTv                             Nice
# 60880     110786               books                       Five Stars
# 60881     161713  mobile accessories                          Valo na
# 60882     144507        refrigerator   Samsung Gear S3 .. Awesome....
# 60883     110121  mobile accessories  Not Happy facing so much issues
# 60884     148315             smartTv                             Good
# 60885     162092             smartTv                       Five Stars
# 60886     164387              mobile                    Best in prise
# 60887     133063             smartTv                    Not gud pbone
# 60888     167823              mobile                    Not recommend
#
#                                              Review_text  Rating Own_Rating
# 60879                                Performance is good       5   Positive
# 60880  A must read for all aspirants who seek to conq...       5   Positive
# 60881                                            Valo na       1   Negative
# 60882                                     Nice ....Watch       5   Positive
# 60883  1) 3.5 mm jack is not supporting any kind of h...       1   Negative
# 60884                                                 Ok       4   Positive
# 60885  Value for money, using since more than 4 month...       5   Positive
# 60886                                 Very nice products       5   Positive
# 60887         Heating problem. Battery backup less than.       3    Neutral
# 60888  fingerprint reader average Camera quality belo...       3    Neutral

# %% [markdown]
# Dropping the rows having a particular value as NaN

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60860 entries, 0 to 60888
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unique_ID      60860 non-null  int64
#  1   Category       60860 non-null  object
#  2   Review_Header  60860 non-null  object
#  3   Review_text    60860 non-null  object
#  4   Rating         60860 non-null  int64
#  5   Own_Rating     60860 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 3.3+ MB

# %%
df.describe(include='all')
# Out:
#             Unique_ID Category Review_Header Review_text        Rating  \
# count    60860.000000    60860         60860       60860  60860.000000
# unique            NaN        5         34601       49883           NaN
# top               NaN   mobile          Good        Good           NaN
# freq              NaN    22743          3155        2316           NaN
# mean    140430.427654      NaN           NaN         NaN      4.080907
# std      17569.029273      NaN           NaN         NaN      1.342249
# min     110000.000000      NaN           NaN         NaN      1.000000
# 25%     125215.750000      NaN           NaN         NaN      4.000000
# 50%     140430.500000      NaN           NaN         NaN      5.000000
# 75%     155645.250000      NaN           NaN         NaN      5.000000
# max     170860.000000      NaN           NaN         NaN      5.000000
#
#        Own_Rating
# count       60860
# unique          3
# top      Positive
# freq        47409
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %% [markdown]
# **SENTIMENT ANALYSIS**

# %%
#Analysing the review sentiments from the datasets
data_sentiment_count=df['Own_Rating'].value_counts()
print(data_sentiment_count)

sns.countplot(x='Own_Rating',data=df,palette=['green','yellow','red'])
plt.title('Sentiment Distribution before analysis')
plt.xlabel('Sentiments')
plt.show()
# Out:
# Positive    47409
# Negative     9086
# Neutral      4365
# Name: Own_Rating, dtype: int64
# <ipython-input-9-329560529f36>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Own_Rating',data=df,palette=['green','yellow','red'])

# %%
#Sentimental analysis using TextBlob and classify sentiments
from textblob import TextBlob

#Take the dataset in different variable
data1=df
def get_sentiment(text):
  analysis=TextBlob(text)
  if analysis.sentiment.polarity>0:
    return 'Positive'
  elif analysis.sentiment.polarity==0:
    return 'neutral'
  else:
    return 'Negative'

#Creating anew column sentiment to store the sentiments
data1['Sentiment']=data1['Review_text'].apply(get_sentiment)

#Count the sentiments
sentiment_counts=data1['Sentiment'].value_counts()
print(sentiment_counts)

#PLotting the sentiment distribution
sns.countplot(x='Sentiment',data=data1,palette=['green','yellow','red'])
plt.title('Sentiment Distribution after analysis')
plt.xlabel('Sentiment')
plt.show()
# Out:
# Positive    47138
# neutral      6935
# Negative     6787
# Name: Sentiment, dtype: int64
# <ipython-input-10-1efbcf3922a6>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment',data=data1,palette=['green','yellow','red'])

# %%
#Sentiment analysis using NLTX Vader and classify sentiments based on their product category
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#take the dataset on different variable
data2=df

sid=SentimentIntensityAnalyzer()
data2['Sentiment Score']=data2['Review_text'].apply(lambda text: sid.polarity_scores(text)['compound'])

#Map sentiment scores to categories
def get_sentiment_category(score):
  if score>=0.05:
    return 'Positive'
  elif score<=-0.05:
    return 'Negative'
  else:
    return 'Neutral'

data2['Sentiment Category']=data2['Sentiment Score'].apply(get_sentiment_category)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
#Count the sentiments
sentiment_counts=data2['Sentiment Category'].value_counts()
print(sentiment_counts)
print()

sentiment_by_category=pd.crosstab(index=data2['Category'],columns=data2['Sentiment Category'])
print(sentiment_by_category)
print()

#Visualize sentiment distribution across categories
plt.figure(figsize=(10,6))
sns.countplot(x='Category',hue='Sentiment Category',data=data2,palette=['green','blue','red'])
plt.title('Sentiment Distribution across platforms')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=30)
plt.legend(title='Sentiment')
plt.show()
# Out:
# Positive    44830
# Negative     9563
# Neutral      6467
# Name: Sentiment Category, dtype: int64
#
# Sentiment Category  Negative  Neutral  Positive
# Category
# books                    244      587      3077
# mobile                  3794     2356     16593
# mobile accessories      2682     1463     10665
# refrigerator             583      459      3744
# smartTv                 2260     1602     10751

# %% [markdown]
# **WORD CLOUD**

# %%
#create word clouds based on the sentiments using the data2 dataset

from wordcloud import WordCloud

#Converting 'review' columnto strings
df['Review_Header']=df['Review_Header'].astype(str)

positive_reviews=''.join(data2[data2['Sentiment Category']=='Positive']['Review_Header'])
negative_reviews=''.join(data2[data2['Sentiment Category']=='Negative']['Review_Header'])
neutral_reviews=''.join(data2[data2['Sentiment Category']=='Neutral']['Review_Header'])

plt.figure(figsize=(10,8))
wordcloud_positive=WordCloud(width=800,height=400,background_color='white').generate(positive_reviews)
plt.imshow(wordcloud_positive,interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Positive Reviews')
plt.show()

# %%
plt.figure(figsize=(10,8))
wordcloud_neutral=WordCloud(width=800,height=400,background_color='white').generate(neutral_reviews)
plt.imshow(wordcloud_neutral,interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Neutral Reviews')
plt.show()

# %%
plt.figure(figsize=(10,8))
wordcloud_negative=WordCloud(width=800,height=400,background_color='white').generate(negative_reviews)
plt.imshow(wordcloud_negative,interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Negative Reviews')
plt.show()

# %% [markdown]
# **INFERENCE**: The Word Cloud gives us a gist of trending keywords according to the respective sentiment

# %% [markdown]
# ADDITIONAL ANALYSIS

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer=CountVectorizer(stop_words='english',max_features=10)
word_frequency=vectorizer.fit_transform(data2['Review_Header'])
words=vectorizer.get_feature_names_out()
word_counts=word_frequency.sum(axis=0).A1

plt.figure(figsize=(8,6))
sns.barplot(x=word_counts,y=words,palette='inferno')
plt.title('Top 10 Frequent Words in  Reviews')
plt.xlabel('Word Count')
plt.ylabel('Words')
plt.show()
# Out:
# <ipython-input-20-84940d2c3b8a>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=word_counts,y=words,palette='inferno')

# %%
top_ratings=df['Rating'].value_counts()

plt.figure(figsize=(10,6))
sns.barplot(x=top_ratings.index,y=top_ratings.values,palette='magma')
plt.title('Most frequent ratings in  Reviews')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()
# Out:
# <ipython-input-21-40f3b8da6788>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_ratings.index,y=top_ratings.values,palette='magma')

# %%
from collections import Counter
# get the most common words in positive sentiments
positive_df=data2[data2['Sentiment Category']=='Positive']

top_positive=Counter([word for sentence in positive_df['Review_text'] for word in sentence.split()
])
top_positive=pd.DataFrame(top_positive.most_common(20))
top_positive=top_positive.iloc[1:,:]
top_positive.columns=['Common_words','count']

top_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_6449c_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_6449c_row1_col1 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_6449c_row2_col1 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_6449c_row3_col1 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_6449c_row4_col1 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_6449c_row5_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_6449c_row6_col1 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_6449c_row7_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_6449c_row8_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_6449c_row9_col1 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_6449c_row10_col1 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_6449c_row11_col1 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_6449c_row12_col1 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_6449c_row13_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_6449c_row14_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_6449c_row15_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_6449c_row16_col1, #T_6449c_row17_col1, #T_6449c_row18_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_6449c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6449c_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_6449c_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6449c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6449c_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_6449c_row0_col1" class="data row0 col1" >31589</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6449c_row1_col0" class="data row1 col0" >and</td>
#       <td id="T_6449c_row1_col1" class="data row1 col1" >27792</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6449c_row2_col0" class="data row2 col0" >to</td>
#       <td id="T_6449c_row2_col1" class="data row2 col1" >20249</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6449c_row3_col0" class="data row3 col0" >for</td>
#       <td id="T_6449c_row3_col1" class="data row3 col1" >18531</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6449c_row4_col0" class="data row4 col0" >a</td>
#       <td id="T_6449c_row4_col1" class="data row4 col1" >18218</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6449c_row5_col0" class="data row5 col0" >I</td>
#       <td id="T_6449c_row5_col1" class="data row5 col1" >16785</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6449c_row6_col0" class="data row6 col0" >this</td>
#       <td id="T_6449c_row6_col1" class="data row6 col1" >15458</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_6449c_row7_col0" class="data row7 col0" >in</td>
#       <td id="T_6449c_row7_col1" class="data row7 col1" >15250</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_6449c_row8_col0" class="data row8 col0" >it</td>
#       <td id="T_6449c_row8_col1" class="data row8 col1" >14888</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_6449c_row9_col0" class="data row9 col0" >good</td>
#       <td id="T_6449c_row9_col1" class="data row9 col1" >14622</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_6449c_row10_col0" class="data row10 col0" >of</td>
#       <td id="T_6449c_row10_col1" class="data row10 col1" >13918</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_6449c_row11_col0" class="data row11 col0" >phone</td>
#       <td id="T_6449c_row11_col1" class="data row11 col1" >11960</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_6449c_row12_col0" class="data row12 col0" >with</td>
#       <td id="T_6449c_row12_col1" class="data row12 col1" >11558</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_6449c_row13_col0" class="data row13 col0" >not</td>
#       <td id="T_6449c_row13_col1" class="data row13 col1" >8475</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_6449c_row14_col0" class="data row14 col0" >very</td>
#       <td id="T_6449c_row14_col1" class="data row14 col1" >8175</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_6449c_row15_col0" class="data row15 col0" >quality</td>
#       <td id="T_6449c_row15_col1" class="data row15 col1" >7736</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_6449c_row16_col0" class="data row16 col0" >Good</td>
#       <td id="T_6449c_row16_col1" class="data row16 col1" >7514</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_6449c_row17_col0" class="data row17 col0" >but</td>
#       <td id="T_6449c_row17_col1" class="data row17 col1" >7466</td>
#     </tr>
#     <tr>
#       <th id="T_6449c_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_6449c_row18_col0" class="data row18 col0" >you</td>
#       <td id="T_6449c_row18_col1" class="data row18 col1" >7441</td>
#     </tr>
#   </tbody>
# </table>

# %%
# get the most common words in negative sentiments
negative_df=data2[data2['Sentiment Category']=='Negative']

top_negative=Counter([word for sentence in negative_df['Review_text'] for word in sentence.split()
])
top_negative=pd.DataFrame(top_negative.most_common(20))
top_negative=top_negative.iloc[1:,:]
top_negative.columns=['Common_words','count']

top_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_42c8f_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_42c8f_row1_col1 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_42c8f_row2_col1 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_42c8f_row3_col1 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_42c8f_row4_col1 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_42c8f_row5_col1 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_42c8f_row6_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_42c8f_row7_col1, #T_42c8f_row8_col1 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_42c8f_row9_col1 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_42c8f_row10_col1 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_42c8f_row11_col1 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_42c8f_row12_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_42c8f_row13_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_42c8f_row14_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_42c8f_row15_col1 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_42c8f_row16_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_42c8f_row17_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_42c8f_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_42c8f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42c8f_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_42c8f_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42c8f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_42c8f_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_42c8f_row0_col1" class="data row0 col1" >6815</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_42c8f_row1_col0" class="data row1 col0" >and</td>
#       <td id="T_42c8f_row1_col1" class="data row1 col1" >5247</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_42c8f_row2_col0" class="data row2 col0" >not</td>
#       <td id="T_42c8f_row2_col1" class="data row2 col1" >5211</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_42c8f_row3_col0" class="data row3 col0" >to</td>
#       <td id="T_42c8f_row3_col1" class="data row3 col1" >4950</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_42c8f_row4_col0" class="data row4 col0" >I</td>
#       <td id="T_42c8f_row4_col1" class="data row4 col1" >4407</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_42c8f_row5_col0" class="data row5 col0" >of</td>
#       <td id="T_42c8f_row5_col1" class="data row5 col1" >3334</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_42c8f_row6_col0" class="data row6 col0" >it</td>
#       <td id="T_42c8f_row6_col1" class="data row6 col1" >3315</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_42c8f_row7_col0" class="data row7 col0" >a</td>
#       <td id="T_42c8f_row7_col1" class="data row7 col1" >3290</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_42c8f_row8_col0" class="data row8 col0" >this</td>
#       <td id="T_42c8f_row8_col1" class="data row8 col1" >3283</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_42c8f_row9_col0" class="data row9 col0" >in</td>
#       <td id="T_42c8f_row9_col1" class="data row9 col1" >2926</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_42c8f_row10_col0" class="data row10 col0" >for</td>
#       <td id="T_42c8f_row10_col1" class="data row10 col1" >2894</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_42c8f_row11_col0" class="data row11 col0" >phone</td>
#       <td id="T_42c8f_row11_col1" class="data row11 col1" >2622</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_42c8f_row12_col0" class="data row12 col0" >but</td>
#       <td id="T_42c8f_row12_col1" class="data row12 col1" >2376</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_42c8f_row13_col0" class="data row13 col0" >very</td>
#       <td id="T_42c8f_row13_col1" class="data row13 col1" >2197</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_42c8f_row14_col0" class="data row14 col0" >with</td>
#       <td id="T_42c8f_row14_col1" class="data row14 col1" >2103</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_42c8f_row15_col0" class="data row15 col0" >good</td>
#       <td id="T_42c8f_row15_col1" class="data row15 col1" >1979</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_42c8f_row16_col0" class="data row16 col0" >quality</td>
#       <td id="T_42c8f_row16_col1" class="data row16 col1" >1815</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_42c8f_row17_col0" class="data row17 col0" >product</td>
#       <td id="T_42c8f_row17_col1" class="data row17 col1" >1615</td>
#     </tr>
#     <tr>
#       <th id="T_42c8f_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_42c8f_row18_col0" class="data row18 col0" >on</td>
#       <td id="T_42c8f_row18_col1" class="data row18 col1" >1553</td>
#     </tr>
#   </tbody>
# </table>

# %%
# get the most common words in neutral sentiments
neutral_df=data2[data2['Sentiment Category']=='Neutral']

top_neutral=Counter([word for sentence in negative_df['Review_text'] for word in sentence.split()
])
top_neutral=pd.DataFrame(top_neutral.most_common(20))
top_neutral=top_neutral.iloc[1:,:]
top_neutral.columns=['Common_words','count']

top_neutral.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_7bc93_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7bc93_row1_col1 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_7bc93_row2_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_7bc93_row3_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_7bc93_row4_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_7bc93_row5_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_7bc93_row6_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_7bc93_row7_col1, #T_7bc93_row8_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_7bc93_row9_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_7bc93_row10_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_7bc93_row11_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_7bc93_row12_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_7bc93_row13_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_7bc93_row14_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_7bc93_row15_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_7bc93_row16_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7bc93_row17_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_7bc93_row18_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_7bc93" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bc93_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_7bc93_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bc93_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7bc93_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_7bc93_row0_col1" class="data row0 col1" >6815</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7bc93_row1_col0" class="data row1 col0" >and</td>
#       <td id="T_7bc93_row1_col1" class="data row1 col1" >5247</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7bc93_row2_col0" class="data row2 col0" >not</td>
#       <td id="T_7bc93_row2_col1" class="data row2 col1" >5211</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7bc93_row3_col0" class="data row3 col0" >to</td>
#       <td id="T_7bc93_row3_col1" class="data row3 col1" >4950</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7bc93_row4_col0" class="data row4 col0" >I</td>
#       <td id="T_7bc93_row4_col1" class="data row4 col1" >4407</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7bc93_row5_col0" class="data row5 col0" >of</td>
#       <td id="T_7bc93_row5_col1" class="data row5 col1" >3334</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_7bc93_row6_col0" class="data row6 col0" >it</td>
#       <td id="T_7bc93_row6_col1" class="data row6 col1" >3315</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_7bc93_row7_col0" class="data row7 col0" >a</td>
#       <td id="T_7bc93_row7_col1" class="data row7 col1" >3290</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_7bc93_row8_col0" class="data row8 col0" >this</td>
#       <td id="T_7bc93_row8_col1" class="data row8 col1" >3283</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_7bc93_row9_col0" class="data row9 col0" >in</td>
#       <td id="T_7bc93_row9_col1" class="data row9 col1" >2926</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_7bc93_row10_col0" class="data row10 col0" >for</td>
#       <td id="T_7bc93_row10_col1" class="data row10 col1" >2894</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_7bc93_row11_col0" class="data row11 col0" >phone</td>
#       <td id="T_7bc93_row11_col1" class="data row11 col1" >2622</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_7bc93_row12_col0" class="data row12 col0" >but</td>
#       <td id="T_7bc93_row12_col1" class="data row12 col1" >2376</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_7bc93_row13_col0" class="data row13 col0" >very</td>
#       <td id="T_7bc93_row13_col1" class="data row13 col1" >2197</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_7bc93_row14_col0" class="data row14 col0" >with</td>
#       <td id="T_7bc93_row14_col1" class="data row14 col1" >2103</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_7bc93_row15_col0" class="data row15 col0" >good</td>
#       <td id="T_7bc93_row15_col1" class="data row15 col1" >1979</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_7bc93_row16_col0" class="data row16 col0" >quality</td>
#       <td id="T_7bc93_row16_col1" class="data row16 col1" >1815</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_7bc93_row17_col0" class="data row17 col0" >product</td>
#       <td id="T_7bc93_row17_col1" class="data row17 col1" >1615</td>
#     </tr>
#     <tr>
#       <th id="T_7bc93_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_7bc93_row18_col0" class="data row18 col0" >on</td>
#       <td id="T_7bc93_row18_col1" class="data row18 col1" >1553</td>
#     </tr>
#   </tbody>
# </table>
